# %% [markdown]
# <a href="https://colab.research.google.com/github/positivejmk/2021-2-practice/blob/master/%EB%84%A4%EC%9D%B4%EB%B2%84%EC%A3%BC%EC%8B%9D%EC%A0%95%EB%B3%B4%ED%81%AC%EB%A1%A4%EB%A7%81_%EC%9C%A0%EB%B3%B4%EC%9C%A8%2C%EB%93%B1%EB%9D%BD%EC%9C%A8%ED%8F%AC%ED%95%A8(%EC%BD%94%EC%8A%A4%ED%94%BC%EB%A7%8C).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import urllib.request #웹에 접근하기 위한 모듈
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
baseurl = "https://finance.naver.com/sise/field_submit.naver?menu=market_sum&returnUrl=http://finance.naver.com/sise/sise_market_sum.naver?page=3&fieldIds=market_sum&fieldIds=per&fieldIds=roe&fieldIds=roa&fieldIds=pbr&fieldIds=reserve_ratio"

# %%
req = requests.get(baseurl)
html = req.text
soup = bs(html, "lxml")

# %%
print(soup)
# Out:
# <!--  global include --><html lang="ko">
# <head>
# <title>시가총액 : 네이버 금융</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="http://finance.naver.com/sise/sise_market_sum.naver" property="og:url"/>
# <meta content="시가총액 : 네이버 금융" property="og:title"/>
# <meta content="관심종목의 실시간 주가를 가장 빠르게 확인하는 곳" property="og:description"/>
# <meta content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png" property="og:image"/>
# <meta content="article" property="og:type"/>
# <meta content="" property="og:article:thumbnailUrl"/>
# <meta content="네이버금융" property="og:article:author"/>
# <meta content="http://FINANCE.NAVER.COM" property="og:article:author:url"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20211021173707/css/finance_header.css" rel="stylesheet" type="text/css"/>
# ...

# %%
headers = soup.select("tr > th")

# %%
print(headers)
# Out:
# [<th scope="col">N</th>, <th scope="col">종목명</th>, <th scope="col">현재가</th>, <th class="tr" scope="col" style="padding-right:8px">전일비</th>, <th scope="col">등락률</th>, <th scope="col">액면가</th>, <th scope="col">시가총액</th>, <th scope="col">PER</th>, <th scope="col">ROE</th>, <th scope="col">ROA</th>, <th scope="col">PBR</th>, <th scope="col">유보율</th>, <th scope="col">토론실</th>]

# %%
stock_datas = soup.select("#contentarea > div.box_type_l > table.type_2 > tbody > tr") #공통주소

# %%
headers = list(map(lambda x: x.text, headers))

# %%
print(headers)
# Out:
# ['N', '종목명', '현재가', '전일비', '등락률', '액면가', '시가총액', 'PER', 'ROE', 'ROA', 'PBR', '유보율', '토론실']

# %%
for data in stock_datas:
  try:
    stock_rank = data.select_one("td.no").text
    stock_name = data.select_one("td:nth-of-type(2) > a").text
    stock_price = data.select_one("td:nth-of-type(3)").text
    stock_updown = data.select_one("td:nth-of-type(5)").text
    stock_reserve = data.select_one("td:nth-of-type(12)").text
    stock_updown = str(stock_updown).strip()
    print(stock_rank, stock_name,stock_price,stock_updown,stock_reserve)
  except AttributeError:
    continue
# Out:
# 1 삼성전자 70,400 +0.28% 9.99
# 2 SK하이닉스 98,500 +2.28% 9.53
# 3 NAVER 407,500 -0.73% 15.22
# 4 삼성바이오로직스 880,000 +1.38% N/A
# 5 LG화학 818,000 +1.49% 2.93
# 6 카카오 127,500 -0.39% 2.70
# 7 삼성전자우 64,200 -0.47% N/A
# 8 삼성SDI 737,000 +1.94% 4.54
# 9 현대차 207,500 0.00% 2.04
# 10 기아 83,400 -0.24% 5.05
# 11 셀트리온 219,500 +0.92% 16.68
# 12 카카오뱅크 60,100 -0.17% 5.08
# 13 POSCO 303,500 -2.41% 3.61
# 14 현대모비스 264,500 -1.12% 4.66
# 15 KB금융 57,600 +0.35% 8.53
# 16 크래프톤 488,000 -1.01% 61.86
# 17 SK이노베이션 256,500 -0.19% -13.58
# 18 삼성물산 120,500 -0.82% 3.81
# 19 SK텔레콤 312,000 +4.70% 6.44
# 20 LG생활건강 1,365,000 -1.59% 17.92
# 21 신한지주 40,050 -0.74% 8.20
# 22 LG전자 125,000 -0.40% 13.23
# 23 SK 252,000 -0.98% 1.11
# 24 SK바이오사이언스 225,000 +0.90% 13.25
# 25 LG 94,600 -0.11% 7.50
# 26 한국전력 22,950 -1.08% 2.91
# 27 삼성생명 70,400 -0.85% 3.53
# 28 하나금융지주 46,150 +0.33% 8.96
# 29 엔씨소프트 628,000 +1.45% 20.83
# 30 하이브 325,000 -1.66% 12.52
# 31 SK아이이테크놀로지 177,000 -0.56% 11.00
# 32 삼성에스디에스 155,500 -0.96% 6.71
# ...

# %%
def one_page_list(page):
    STOCKLIST_URL = "https://finance.naver.com/sise/field_submit.naver?menu=market_sum&returnUrl=http://finance.naver.com/sise/sise_market_sum.naver?page={}&fieldIds=market_sum&fieldIds=per&fieldIds=roe&fieldIds=roa&fieldIds=pbr&fieldIds=reserve_ratio".format(page) #주소설정
    
    response = urllib.request.urlopen(STOCKLIST_URL)
    STOCKLIST_HTML = response.read()
    
    soup = bs(STOCKLIST_HTML)

    
    STOCK_NAME_LIST = []
    STOCK_UPDOWN_LIST = []
    STOCK_PER_LIST = []
    STOCK_ROE_LIST = []
    STOCK_RESERVE_LIST = []

    stock_datas = soup.select("#contentarea > div.box_type_l > table.type_2 > tbody > tr")

    for data in stock_datas:
      try:
        #stock_rank = data.select_one("td.no").text
        stock_name = data.select_one("td:nth-of-type(2) > a").text
        stock_updown = data.select_one("td:nth-of-type(5)").text
        stock_per = data.select_one("td:nth-of-type(8)").text
        stock_roe = data.select_one("td:nth-of-type(9)").text
        stock_reserve = data.select_one("td:nth-of-type(12)").text
        
        stock_updown = str(stock_updown).strip()

        STOCK_NAME_LIST.append(stock_name)
        STOCK_UPDOWN_LIST.append(stock_updown)
        STOCK_PER_LIST.append(stock_per)
        STOCK_ROE_LIST.append(stock_roe)
        STOCK_RESERVE_LIST.append(stock_reserve)
        
      except AttributeError:
        continue

    STOCK_LIST = []

    for i in range(len(STOCK_NAME_LIST)):
        stockInfo = [STOCK_NAME_LIST[i],STOCK_UPDOWN_LIST[i],STOCK_PER_LIST[i],STOCK_ROE_LIST[i],STOCK_RESERVE_LIST[i]]
        STOCK_LIST.append(stockInfo)

    return pd.DataFrame(STOCK_LIST,columns=('종목명','등락률','PER','ROE','유보율'))

one_page_list(1)
# Out:
#            종목명      등락률        PER    ROE     유보율
# 0         삼성전자   +0.14%  5,969,783  51.42    9.99
# 1       SK하이닉스   +2.03%    728,002  47.11    9.53
# 2        NAVER   -1.23%    164,263  56.56   15.22
# 3         LG화학   +0.86%     70,592  47.29    2.93
# 4     삼성바이오로직스   -0.45%     66,165  10.63     N/A
# 5          카카오   -1.18%    445,361  30.22    2.70
# 6        삼성전자우   -0.31%    822,887  74.42     N/A
# 7        삼성SDI   -0.41%     68,765  44.91    4.54
# 8          현대차   +1.93%    213,668  28.72    2.04
# 9           기아   +1.20%    405,363  34.78    5.05
# 10        셀트리온   -1.37%    137,935  20.82   16.68
# 11       카카오뱅크   -0.50%    475,100   5.15    5.08
# 12       POSCO   +3.13%     87,187  54.41    3.61
# 13       현대모비스   +1.51%     94,793  35.00    4.66
# 14        KB금융   +2.26%    415,808  68.57    8.53
# 15        크래프톤   -0.20%     48,951   6.32   61.86
# 16     SK이노베이션   -0.19%     92,466  24.86  -13.58
# 17        삼성물산   -0.41%    186,887  15.30    3.81
# ...

# %%
import time
from itertools import count

def all_page_list():

    FINAL_LIST = []

    for page in range(33):
        one_page_data = one_page_list(page+1)
        print("{}페이지 진행 중 입니다.".format(page+1))
            
        if one_page_data is None:
            break
            
        FINAL_LIST.append(one_page_data)
        time.sleep(3)
    
    return pd.concat(FINAL_LIST)

ALL_STOCK_LIST = all_page_list()

ALL_STOCK_LIST
# Out:
# 1페이지 진행 중 입니다.
# 2페이지 진행 중 입니다.
# 3페이지 진행 중 입니다.
# 4페이지 진행 중 입니다.
# 5페이지 진행 중 입니다.
# 6페이지 진행 중 입니다.
# 7페이지 진행 중 입니다.
# 8페이지 진행 중 입니다.
# 9페이지 진행 중 입니다.
# 10페이지 진행 중 입니다.
# 11페이지 진행 중 입니다.
# 12페이지 진행 중 입니다.
# 13페이지 진행 중 입니다.
# 14페이지 진행 중 입니다.
# 15페이지 진행 중 입니다.
# 16페이지 진행 중 입니다.
# 17페이지 진행 중 입니다.
# 18페이지 진행 중 입니다.
# 19페이지 진행 중 입니다.
# 20페이지 진행 중 입니다.
# 21페이지 진행 중 입니다.
# 22페이지 진행 중 입니다.
# 23페이지 진행 중 입니다.
# 24페이지 진행 중 입니다.
# 25페이지 진행 중 입니다.
# 26페이지 진행 중 입니다.
# 27페이지 진행 중 입니다.
# 28페이지 진행 중 입니다.
# 29페이지 진행 중 입니다.
# 30페이지 진행 중 입니다.
# 31페이지 진행 중 입니다.
# 32페이지 진행 중 입니다.
# 33페이지 진행 중 입니다.
#                         종목명     등락률        PER    ROE    유보율
# 0                      삼성전자   0.00%  5,969,783  51.42   9.99
# 1                    SK하이닉스  +2.03%    728,002  47.11   9.53
# 2                     NAVER  -1.10%    164,263  56.56  15.22
# 3                      LG화학  +0.73%     70,592  47.29   2.93
# 4                  삼성바이오로직스  -0.45%     66,165  10.63    N/A
# ...

# %%
ALL_STOCK_LIST
# Out:
#                         종목명     등락률        PER    ROE    유보율
# 0                      삼성전자   0.00%  5,969,783  51.42   9.99
# 1                    SK하이닉스  +2.03%    728,002  47.11   9.53
# 2                     NAVER  -1.10%    164,263  56.56  15.22
# 3                      LG화학  +0.73%     70,592  47.29   2.93
# 4                  삼성바이오로직스  -0.45%     66,165  10.63    N/A
# ..                      ...     ...        ...    ...    ...
# 45  미래에셋 인버스 전기전자 Core5 ETN  -0.60%      2,000   0.00    N/A
# 46            TIGER 200 산업재  +1.24%        760   1.17    N/A
# 47            KBSTAR 200중공업  +5.49%        460   0.00    N/A
# 48        KINDEX 국채선물10년인버스   0.00%         50   0.00    N/A
# 49       대신 인버스 아연선물 ETN(H)  -2.11%        700   0.00    N/A
#
# [1650 rows x 5 columns]

# %%
ALL_STOCK_LIST.to_csv("/content/drive/MyDrive/Colab Notebooks/2021년(제2회) NH투자증권 빅데이터 경진대회/stock_crawling.csv", sep = ",", encoding = "utf-8")
